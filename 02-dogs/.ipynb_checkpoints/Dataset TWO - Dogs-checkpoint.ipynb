# %% [markdown]
# # Homework 7, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/).
#
# Some of the questions get kind of weird in this one, especially later on. **Feel free to lean on ChatGPT for the crazier ones!** It might be an interesting exploration of how to ask problems or explain what your dataset looks like.

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx",
                  nrows=30000,
                  na_values=['Unknown', 'UNKNOWN'])
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.

# %%
df.shape
# Out:
# (30000, 15)

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Owner Zip Code          30000 non-null  int64
#  1   Animal Name             29539 non-null  object
#  2   Animal Gender           30000 non-null  object
#  3   Primary Breed           25223 non-null  object
#  4   Secondary Breed         3974 non-null   object
#  5   Animal Dominant Color   29885 non-null  object
#  6   Animal Secondary Color  20946 non-null  object
#  7   Animal Third Color      6629 non-null   object
#  8   Animal Birth            30000 non-null  datetime64[ns]
#  9   Spayed or Neut          30000 non-null  object
#  10  Guard or Trained        19826 non-null  object
#  11  Vaccinated              30000 non-null  object
#  12  Application Date        30000 non-null  datetime64[ns]
#  13  License Issued Date     30000 non-null  datetime64[ns]
# ...

# %%
# Owner Zip Code is a column that shows which zip code the dog's owner lives in.
# License Issued Date is the date on which the dog's license was issued
# Spayed or Neut shows whether a dog was spayed or neutered

# %% [markdown]
# # Your thoughts
#
# Think of three questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %% [markdown]
# 1. Which zip code has the most dogs?
# 2. How many dogs were born in the last 5 years? what are their breeds?
# 3. How many licenses expired in the last year?

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %%
df['Primary Breed'].value_counts().head(10)
# Out:
# Primary Breed
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Beagle                                   546
# Name: count, dtype: int64

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown

# %%
import matplotlib as plt
df['Primary Breed'].value_counts().head(10).sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='Primary Breed'>

# %% [markdown]
# ## What are the most popular dog names?

# %%
df['Animal Name'].value_counts().head(10)
# Out:
# Animal Name
# Max        202
# Bella      193
# Charlie    172
# Lola       146
# Rocky      140
# Lucy       128
# Coco       114
# Buddy      113
# Lucky      106
# Daisy       90
# Name: count, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'] == 'Hazel']
# Out:
#        Owner Zip Code Animal Name Animal Gender  \
# 1119            10014       Hazel             F
# 1359            11434       Hazel             F
# 2970            10019       Hazel             F
# 3345            10472       Hazel             F
# 4410            11369       Hazel             F
# 5717            10013       Hazel             F
# 7118            10012       Hazel             F
# 8312            11208       Hazel             M
# 9062            11207       Hazel             F
# 11795           10469       Hazel             F
# 14353           11238       Hazel             F
# 17116           10314       Hazel             F
# 18125           10309       Hazel             F
# 18648           10314       Hazel             F
# 19003           11218       Hazel             F
# 19830           10306       Hazel             F
# 20644           10128       Hazel             F
# 21979           10031       Hazel             F
# ...

# %%
len(df[df['Animal Name'] == 'Max'])
# Out:
# 202

# %%
len(df[df['Animal Name'] == 'Maxwell'])
# Out:
# 11

# %% [markdown]
# ## What percentage of dogs are guard dogs?
#
# Check out the documentation for [value counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html).

# %%
df['Guard or Trained'].value_counts(normalize=True).replace({
    'No': 'Trained',
    'Yes': 'Guard'
})
# Out:
# Guard or Trained
# No     0.999143
# Yes    0.000857
# Name: proportion, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df['Guard or Trained'].value_counts().dropna()
# Out:
# Guard or Trained
# No     19809
# Yes       17
# Name: count, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`

# %%
df['Guard or Trained'].value_counts()
# Out:
# Guard or Trained
# No     19809
# Yes       17
# Name: count, dtype: int64

# %% [markdown]
# ## Fill in all of those empty "Guard or Trained" columns with "No"
#
# **We're maing a big assumption** here that if they aren't listed as guard dogs, they probably aren't guard dogs.
#
# Look up `.fillna`. Check your result with another `.value_counts()`

# %%
df['Guard or Trained'].head()
# Out:
# 0     No
# 1     No
# 2    NaN
# 3     No
# 4    NaN
# Name: Guard or Trained, dtype: object

# %%
df['Guard or Trained'] = df['Guard or Trained'].fillna('No')
df['Guard or Trained']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 29995    No
# 29996    No
# 29997    No
# 29998    No
# 29999    No
# Name: Guard or Trained, Length: 30000, dtype: object

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
guard_dogs = df[df['Guard or Trained'] == 'Guard']
guard_dogs['Primary Breed'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with `df['Animal Birth'].dt.year` or `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
df['Year'] = df['Animal Birth'].dt.year
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
present_year = 2024
df['Age'] = present_year - df['Year']
# df.head()
df['Age'].median()
# Out:
# np.float64(14.0)

# %% [markdown]
# # Joining data together

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**
#
# Here's an example of how you can merge two dataframes:
#
# ```python
# merged = prisons_df.merge(states_df, left_on='state', right_on='name')
# ```
#
# In the example above, `prisons_df` has a column called `state` that matches with the `name` column of `states_df`. The columns of `states_df` are then added to `prisons_df` and returned as a new dataframe called `merged`.
#
# > **Rows without a match get discarded because it is an [inner join](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html).** I think left joins are probably the most common (keep rows from the "left" df even if they don't have a match in the right. For example, by default a prison with the state of `PUERTO RICO` would be dropped if PR wasn't in `states_df`, but if you changed it to `how='left'` it would be preserved, but the additional columns would just be `NaN`.

# %%
neighborhood = pd.read_csv("zipcodes-neighborhoods.csv")
# neighborhood
merged = neighborhood.merge(df, left_on='zip', right_on='Owner Zip Code')
merged.head()
# Out:
#     neighborhood    zip borough  Owner Zip Code Animal Name Animal Gender  \
# 0  Central Bronx  10453   Bronx           10453      T-Bone             M
# 1  Central Bronx  10453   Bronx           10453        Cici             F
# 2  Central Bronx  10453   Bronx           10453        Blue             M
# 3  Central Bronx  10453   Bronx           10453         Boi             M
# 4  Central Bronx  10453   Bronx           10453  MARSHMELLO             F
#
#                           Primary Breed Secondary Breed Animal Dominant Color  \
# 0                               Bulldog             NaN                 White
# 1  American Pit Bull Mix / Pit Bull Mix             NaN                 BROWN
# 2                          Basset Hound             NaN                 Brown
# 3                     Yorkshire Terrier             NaN                 Black
# 4                               Samoyed             NaN                 WHITE
#
# ...

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?

# %%
bronx_dogs = merged[merged['borough'] == 'Bronx']
bronx_dogs['Animal Name'].value_counts().head(1)
# Out:
# Animal Name
# Bella    22
# Name: count, dtype: int64

# %%
brooklyn_dogs = merged[merged['borough'] == 'Brooklyn']
brooklyn_dogs['Animal Name'].value_counts().head(1)
# Out:
# Animal Name
# Max    46
# Name: count, dtype: int64

# %%
ues_dogs = merged[merged['neighborhood'] == 'Upper East Side']
ues_dogs['Animal Name'].value_counts().head(1)
# Out:
# Animal Name
# Charlie    19
# Name: count, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?

# %%
common_breeds = merged.groupby('neighborhood')['Primary Breed'].apply(lambda x: x.value_counts().idxmax())
common_breeds.reset_index()
# Out:
#                      neighborhood                         Primary Breed
# 0                    Borough Park                     Yorkshire Terrier
# 1          Bronx Park and Fordham                     Yorkshire Terrier
# 2       Bushwick and Williamsburg                     Yorkshire Terrier
# 3          Canarsie and Flatlands                              Shih Tzu
# 4                   Central Bronx                     Yorkshire Terrier
# 5                Central Brooklyn                              Shih Tzu
# 6                  Central Harlem                             Chihuahua
# 7                  Central Queens                     Yorkshire Terrier
# 8             Chelsea and Clinton                             Chihuahua
# 9                     East Harlem                     Yorkshire Terrier
# 10     East New York and New Lots                     Yorkshire Terrier
# 11                       Flatbush                              Shih Tzu
# ...

# %% [markdown]
# ## Make a new column called monochrome that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?
#
# Be conscious of case-sensitivity! `WHITE` and `white` aren't the same, so you might need to standardize first.
#
# Using `.isin` is going to be very helpful.

# %%
merged.head(30)
# Out:
#      neighborhood    zip borough  Owner Zip Code              Animal Name  \
# 0   Central Bronx  10453   Bronx           10453                   T-Bone
# 1   Central Bronx  10453   Bronx           10453                     Cici
# 2   Central Bronx  10453   Bronx           10453                     Blue
# 3   Central Bronx  10453   Bronx           10453                      Boi
# 4   Central Bronx  10453   Bronx           10453               MARSHMELLO
# 5   Central Bronx  10453   Bronx           10453                    Amber
# 6   Central Bronx  10453   Bronx           10453                  Blackie
# 7   Central Bronx  10453   Bronx           10453                   Jewels
# 8   Central Bronx  10453   Bronx           10453                  Casper
# 9   Central Bronx  10453   Bronx           10453                      Sol
# 10  Central Bronx  10453   Bronx           10453                   Magnus
# 11  Central Bronx  10453   Bronx           10453                     Zeus
# ...

# %%
merged ['Animal Dominant Color'] = merged['Animal Dominant Color'].replace({
    'WHITE': 'White',
    'BLACK': 'Black',
    'GRAY': 'Gray'})
merged ['Animal Secondary Color'] = merged['Animal Secondary Color'].replace({
    'WHITE': 'White',
    'BLACK': 'Black',
    'GRAY': 'Gray'})
merged ['Animal Third Color'] = merged['Animal Third Color'].replace({
    'WHITE': 'White',
    'BLACK': 'Black',
    'GRAY': 'Gray'})
monochrome_colors = ['White', 'Black', 'Grey']
merged['monochrome'] = (merged['Animal Dominant Color'].isin(monochrome_colors) & 
                        merged['Animal Secondary Color'].isin(monochrome_colors) &
                        merged['Animal Third Color'].isin(monochrome_colors))

merged['monochrome'].value_counts()
# Out:
# monochrome
# False    29504
# True        69
# Name: count, dtype: int64

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
merged['borough'].value_counts().sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='borough'>

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
boropop = pd.read_csv("boro_population.csv")
# boropop
newmerged = boropop.merge(merged, left_on='borough', right_on='borough')
# newmerged
dog_count = newmerged['borough'].value_counts()
boropop['dog_count'] = boropop['borough'].map(dog_count) #i swear i only used chatgpt for this .map part and did the rest on my own
boropop['dogs_per_capita'] = boropop['dog_count'] / boropop['population']
dpc = boropop.sort_values('dogs_per_capita', ascending=False)
dpc
# Out:
#          borough  population  area_sqmi  dog_count  dogs_per_capita
# 0      Manhattan     1644518         23      10478         0.006371
# 4  Staten Island      474558         59       2727         0.005746
# 2       Brooklyn     2636735         71       7466         0.002832
# 3         Queens     2339150        109       6154         0.002631
# 1          Bronx     1455444         42       2748         0.001888

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? This is very crazy, so ask in Slack, or a TA, or our buddy ChatGPT.

# %%
import matplotlib.pyplot as plt
breed_by_boro = newmerged.groupby('borough')['Primary Breed'].value_counts()
breed_by_boro = breed_by_boro.reset_index(name='count')
top_breeds_by_boro = breed_by_boro.groupby('borough').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)
for borough in top_breeds_by_boro['borough'].unique():
    subset = top_breeds_by_boro[top_breeds_by_boro['borough'] == borough]
    plt.bar(subset['Primary Breed'], subset['count'], label=borough)

plt.title('Top 5 Breeds in Each Borough')
plt.xlabel('Primary Breed')
plt.ylabel('Count')
plt.legend(title='Borough')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/3t/356b2m1s0713vmrmjlw72vfm0000gn/T/ipykernel_6842/2334429522.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_breeds_by_boro = breed_by_boro.groupby('borough').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)
